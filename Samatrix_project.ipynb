# %%
import pandas  as pd

# %%
df=pd.read_csv("MovieData.csv")
print("Dimensions of the DataFrame:")
print("Number of Rows:", df.shape[0],"Number of Columns:", df.shape[1])
print("\nNull Value Information:")
print(df.isnull().sum())
print("\nSummary Statistics of Numeric Columns:")
print(df.describe())
print("Column-wise Information:")
print(df.info())
print("Column Data Types:")
print(df.dtypes)
print("\nNon-Null Counts:")
print(df.count())
# summary statistics for numeric columns
numeric_summary = df.describe()

# summary statistics
print("Summary Statistics for Numeric Columns:")
print(numeric_summary)
df['Gross'] /= 1000000
df['budget'] /= 1000000
print(df)

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
 
# 1. Create a new column 'profit' by calculating the difference between 'gross' and 'budget'
df['profit'] = df['Gross'] - df['budget']

# 2. Sort the DataFrame based on the 'profit' column
df_sorted = df.sort_values(by='profit', ascending=False)

# 3. Extract the top ten profiting movies and store them in a new DataFrame - 'top10'
top10 = df_sorted.head(10)

# 4. Plot a scatter or joint plot between 'budget' and 'profit'
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_sorted, x='budget', y='profit', palette='viridis')
plt.title("Scatter Plot of Budget vs. Profit")
plt.xlabel("Budget (in million $)")
plt.ylabel("Profit (in million $)")
plt.show()

# 5. Extract movies with negative profit and store them in 'neg_profit' DataFrame
neg_profit = df[df['profit'] < 0]

# Display the 'top10' and 'neg_profit' DataFrames
print("Top 10 Profiting Movies:")
print(top10)

print("\nMovies with Negative Profit:")
print(neg_profit)


# Create the new 'profit' column
df['profit'] = df['Gross'] - df['budget']
print(df)

df_sorted = df.sort_values(by='profit', ascending=False)
print(df_sorted)

# Extract the top 10 profitable movies using position-based indexing (rows 0-9)
top10 = df_sorted.iloc[0:10]

# Display the top 10 profitable movies
print(top10)

# Create the 'profit' column
df['profit'] = df['Gross'] - df['budget']

# Plot scatter plot of 'profit' vs 'budget'
plt.figure(figsize=(10, 6))
plt.scatter(df['budget'], df['profit'], alpha=0.5)
plt.title("Profit vs Budget")
plt.xlabel("Budget (in million $)")
plt.ylabel("Profit (in million $)")
plt.grid(True)
plt.show()

# Filter movies with negative profit
neg_profit = df[df['profit'] < 0]

# Display movies with negative profit
print(neg_profit)
# Out:
# Dimensions of the DataFrame:
# Number of Rows: 100 Number of Columns: 62
#
# Null Value Information:
# Title             0
# title_year        0
# budget            0
# Gross             0
# actor_1_name      0
#                  ..
# Votes1000         0
# VotesUS           0
# VotesnUS          0
# content_rating    0
# Country           0
# Length: 62, dtype: int64
#
# Summary Statistics of Numeric Columns:
#         title_year        budget         Gross  actor_1_facebook_likes  \
# count   100.000000  1.000000e+02  1.000000e+02              100.000000
# mean   2012.820000  7.838400e+07  1.468679e+08            13407.270000
# std       1.919491  7.445295e+07  1.454004e+08            10649.037862
# min    2010.000000  3.000000e+06  2.238380e+05               39.000000
# 25%    2011.000000  1.575000e+07  4.199752e+07             1000.000000
# 50%    2013.000000  4.225000e+07  1.070266e+08            13000.000000
# ...
